# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
#remove average value of each sample from its values
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x/400
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1
NF = 5

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 50, 5)             60
#
#  average_pooling1d_3 (Averag  (None, 10, 5)            0
#  ePooling1D)
#
#  conv1d_6 (Conv1D)           (None, 4, 5)              180
#
#  flatten_3 (Flatten)         (None, 20)                0
#
#  dense_7 (Dense)             (None, 12)                252
#
#  dropout_4 (Dropout)         (None, 12)                0
#
#  dense_8 (Dense)             (None, 3)                 39
#
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv1D at 0x7f0996fbfe50>,
#  <keras.layers.pooling.AveragePooling1D at 0x7f0995d235e0>,
#  <keras.layers.convolutional.Conv1D at 0x7f0995b7fc70>,
#  <keras.layers.core.flatten.Flatten at 0x7f0995d4f730>,
#  <keras.layers.core.dense.Dense at 0x7f0995d7a490>,
#  <keras.layers.core.dropout.Dropout at 0x7f0995b7e6a0>,
#  <keras.layers.core.dense.Dense at 0x7f0995d2fb20>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 250
EPOCHS = 100

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/100
# 32/32 - 2s - loss: 1.1166 - accuracy: 0.3440 - val_loss: 1.1055 - val_accuracy: 0.3670 - 2s/epoch - 77ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 1.0984 - accuracy: 0.3943 - val_loss: 1.0893 - val_accuracy: 0.3910 - 194ms/epoch - 6ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 1.0744 - accuracy: 0.4755 - val_loss: 1.0572 - val_accuracy: 0.5305 - 201ms/epoch - 6ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 1.0298 - accuracy: 0.5691 - val_loss: 0.9961 - val_accuracy: 0.6545 - 218ms/epoch - 7ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 0
ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 0.1527 - accuracy: 0.9614 - val_loss: 0.1377 - val_accuracy: 0.9630 - 194ms/epoch - 6ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 0.1621 - accuracy: 0.9589 - val_loss: 0.1450 - val_accuracy: 0.9605 - 201ms/epoch - 6ms/step
# Epoch 93/100
# 32/32 - 0s - loss: 0.1547 - accuracy: 0.9606 - val_loss: 0.1398 - val_accuracy: 0.9630 - 196ms/epoch - 6ms/step
# Epoch 94/100
# 32/32 - 0s - loss: 0.1534 - accuracy: 0.9591 - val_loss: 0.1363 - val_accuracy: 0.9625 - 229ms/epoch - 7ms/step
# Epoch 95/100
# 32/32 - 0s - loss: 0.1517 - accuracy: 0.9616 - val_loss: 0.1375 - val_accuracy: 0.9650 - 204ms/epoch - 6ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 0.1502 - accuracy: 0.9622 - val_loss: 0.1388 - val_accuracy: 0.9620 - 195ms/epoch - 6ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 0.1533 - accuracy: 0.9610 - val_loss: 0.1318 - val_accuracy: 0.9650 - 195ms/epoch - 6ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 0.1462 - accuracy: 0.9640 - val_loss: 0.1322 - val_accuracy: 0.9645 - 187ms/epoch - 6ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 0.1497 - accuracy: 0.9617 - val_loss: 0.1325 - val_accuracy: 0.9650 - 195ms/epoch - 6ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 0.1445 - accuracy: 0.9629 - val_loss: 0.1361 - val_accuracy: 0.9635 - 280ms/epoch - 9ms/step

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 250
EPOCHS2 = 100

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 32/32 - 1s - loss: 1.0674 - accuracy: 0.4364 - val_loss: 0.9576 - val_accuracy: 0.6285 - 837ms/epoch - 26ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 0.8390 - accuracy: 0.6908 - val_loss: 0.7006 - val_accuracy: 0.7915 - 197ms/epoch - 6ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 0.6360 - accuracy: 0.7889 - val_loss: 0.5213 - val_accuracy: 0.8545 - 199ms/epoch - 6ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 0.5070 - accuracy: 0.8503 - val_loss: 0.4290 - val_accuracy: 0.8870 - 196ms/epoch - 6ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 0.4230 - accuracy: 0.8829 - val_loss: 0.3532 - val_accuracy: 0.9075 - 192ms/epoch - 6ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 0.3714 - accuracy: 0.9050 - val_loss: 0.3057 - val_accuracy: 0.9250 - 191ms/epoch - 6ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 0.3262 - accuracy: 0.9170 - val_loss: 0.2787 - val_accuracy: 0.9340 - 210ms/epoch - 7ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 0.3028 - accuracy: 0.9268 - val_loss: 0.2553 - val_accuracy: 0.9385 - 214ms/epoch - 7ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 0.2839 - accuracy: 0.9306 - val_loss: 0.2485 - val_accuracy: 0.9375 - 192ms/epoch - 6ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 0.2687 - accuracy: 0.9351 - val_loss: 0.2311 - val_accuracy: 0.9405 - 194ms/epoch - 6ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 0.2568 - accuracy: 0.9405 - val_loss: 0.2219 - val_accuracy: 0.9490 - 194ms/epoch - 6ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 0.2384 - accuracy: 0.9455 - val_loss: 0.2048 - val_accuracy: 0.9560 - 219ms/epoch - 7ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 0.2332 - accuracy: 0.9441 - val_loss: 0.1957 - val_accuracy: 0.9585 - 205ms/epoch - 6ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 0.2242 - accuracy: 0.9494 - val_loss: 0.1949 - val_accuracy: 0.9570 - 198ms/epoch - 6ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 0.2174 - accuracy: 0.9501 - val_loss: 0.1899 - val_accuracy: 0.9605 - 191ms/epoch - 6ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 0.2057 - accuracy: 0.9546 - val_loss: 0.1742 - val_accuracy: 0.9655 - 192ms/epoch - 6ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 0.2030 - accuracy: 0.9551 - val_loss: 0.1785 - val_accuracy: 0.9610 - 194ms/epoch - 6ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 0
ms/step
# Epoch 75/100
# 32/32 - 0s - loss: 0.0890 - accuracy: 0.9822 - val_loss: 0.0782 - val_accuracy: 0.9845 - 189ms/epoch - 6ms/step
# Epoch 76/100
# 32/32 - 0s - loss: 0.0899 - accuracy: 0.9805 - val_loss: 0.0794 - val_accuracy: 0.9840 - 188ms/epoch - 6ms/step
# Epoch 77/100
# 32/32 - 0s - loss: 0.0915 - accuracy: 0.9791 - val_loss: 0.0819 - val_accuracy: 0.9825 - 192ms/epoch - 6ms/step
# Epoch 78/100
# 32/32 - 0s - loss: 0.0931 - accuracy: 0.9784 - val_loss: 0.0834 - val_accuracy: 0.9835 - 193ms/epoch - 6ms/step
# Epoch 79/100
# 32/32 - 0s - loss: 0.0869 - accuracy: 0.9820 - val_loss: 0.0801 - val_accuracy: 0.9840 - 191ms/epoch - 6ms/step
# Epoch 80/100
# 32/32 - 0s - loss: 0.0915 - accuracy: 0.9800 - val_loss: 0.0808 - val_accuracy: 0.9810 - 188ms/epoch - 6ms/step
# Epoch 81/100
# 32/32 - 0s - loss: 0.0882 - accuracy: 0.9806 - val_loss: 0.0775 - val_accuracy: 0.9830 - 188ms/epoch - 6ms/step
# Epoch 82/100
# 32/32 - 0s - loss: 0.0875 - accuracy: 0.9785 - val_loss: 0.0793 - val_accuracy: 0.9830 - 204ms/epoch - 6ms/step
# Epoch 83/100
# 32/32 - 0s - loss: 0.0850 - accuracy: 0.9818 - val_loss: 0.0764 - val_accuracy: 0.9835 - 190ms/epoch - 6ms/step
# Epoch 84/100
# 32/32 - 0s - loss: 0.0866 - accuracy: 0.9818 - val_loss: 0.0784 - val_accuracy: 0.9835 - 188ms/epoch - 6ms/step
# Epoch 85/100
# 32/32 - 0s - loss: 0.0853 - accuracy: 0.9810 - val_loss: 0.0753 - val_accuracy: 0.9840 - 192ms/epoch - 6ms/step
# Epoch 86/100
# 32/32 - 0s - loss: 0.0843 - accuracy: 0.9814 - val_loss: 0.0783 - val_accuracy: 0.9835 - 186ms/epoch - 6ms/step
# Epoch 87/100
# 32/32 - 0s - loss: 0.0851 - accuracy: 0.9811 - val_loss: 0.0792 - val_accuracy: 0.9840 - 184ms/epoch - 6ms/step
# Epoch 88/100
# 32/32 - 0s - loss: 0.0839 - accuracy: 0.9809 - val_loss: 0.0806 - val_accuracy: 0.9820 - 188ms/epoch - 6ms/step
# Epoch 89/100
# 32/32 - 0s - loss: 0.0867 - accuracy: 0.9818 - val_loss: 0.0748 - val_accuracy: 0.9850 - 189ms/epoch - 6ms/step
# Epoch 90/100
# 32/32 - 0s - loss: 0.0807 - accuracy: 0.9824 - val_loss: 0.0733 - val_accuracy: 0.9845 - 187ms/epoch - 6ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 0.0820 - accuracy: 0.9819 - val_loss: 0.0839 - val_accuracy: 0.9805 - 190ms/epoch - 6ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 0.0851 - accuracy: 0.9806 - val_loss: 0.0769 - val_accuracy: 0.9830 - 193ms/epoch - 6ms/step
# Epoch 93/100
# 32/32 - 0s - loss: 0.0823 - accuracy: 0.9822 - val_loss: 0.0768 - val_accuracy: 0.9825 - 187ms/epoch - 6ms/step
# Epoch 94/100
# 32/32 - 0s - loss: 0.0805 - accuracy: 0.9816 - val_loss: 0.0782 - val_accuracy: 0.9830 - 188ms/epoch - 6ms/step
# Epoch 95/100
# 32/32 - 0s - loss: 0.0862 - accuracy: 0.9800 - val_loss: 0.0761 - val_accuracy: 0.9825 - 190ms/epoch - 6ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 0.0792 - accuracy: 0.9843 - val_loss: 0.0761 - val_accuracy: 0.9830 - 192ms/epoch - 6ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 0.0823 - accuracy: 0.9820 - val_loss: 0.0738 - val_accuracy: 0.9830 - 190ms/epoch - 6ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 0.0793 - accuracy: 0.9839 - val_loss: 0.0748 - val_accuracy: 0.9820 - 190ms/epoch - 6ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 0.0778 - accuracy: 0.9839 - val_loss: 0.0704 - val_accuracy: 0.9860 - 188ms/epoch - 6ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 0.0781 - accuracy: 0.9819 - val_loss: 0.0723 - val_accuracy: 0.9845 - 188ms/epoch - 6ms/step

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
