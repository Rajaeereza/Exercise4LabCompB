# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
#remove average value of each sample from its values
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x/400
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1
NF = 5

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=6, kernel_size=3, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    
    model.add(Conv1D(filters=8, kernel_size=9, 
                     activation='relu'))
    model.add(Conv1D(filters=4, kernel_size=3, 
                     activation='relu'))
    model.add(tf.keras.layers.GlobalMaxPooling1D())
    model.add(Flatten())
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# Model: "sequential_48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_120 (Conv1D)         (None, 58, 6)             24
#
#  conv1d_121 (Conv1D)         (None, 50, 8)             440
#
#  conv1d_122 (Conv1D)         (None, 48, 4)             100
#
#  global_max_pooling1d_1 (Glo  (None, 4)                0
#  balMaxPooling1D)
#
#  flatten_39 (Flatten)        (None, 4)                 0
#
#  dense_79 (Dense)            (None, 3)                 15
#
# =================================================================
# Total params: 579
# Trainable params: 579
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv1D at 0x7f8d4d229250>,
#  <keras.layers.convolutional.Conv1D at 0x7f8d4e40c190>,
#  <keras.layers.convolutional.Conv1D at 0x7f8d4cbb8730>,
#  <keras.layers.pooling.GlobalMaxPooling1D at 0x7f8d28d99a60>,
#  <keras.layers.core.flatten.Flatten at 0x7f8d4867d9d0>,
#  <keras.layers.core.dense.Dense at 0x7f8d4d2297c0>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-d64b01653919> in <module>
#      27     plt.show()
#      28
# ---> 29 Show_weights(model,0)
#      30 Show_weights(model,2)
#
# <ipython-input-74-d64b01653919> in Show_weights(model, l, label)
#      14     ax.plot((0,))
#      15     for i in range(M):
# ---> 16         ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
#      17     ax.set_title(label+': filters of layer '+str(l))
#      18     ax.set_xlabel('index')
#
# IndexError: list index out of range

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 250
EPOCHS = 100

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/100
# 32/32 - 5s - loss: 1.0908 - accuracy: 0.4079 - val_loss: 1.0761 - val_accuracy: 0.4335 - 5s/epoch - 159ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 1.0498 - accuracy: 0.4663 - val_loss: 1.0149 - val_accuracy: 0.5385 - 448ms/epoch - 14ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 0.9730 - accuracy: 0.5658 - val_loss: 0.9321 - val_accuracy: 0.5860 - 359ms/epoch - 11ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 0.8838 - accuracy: 0.6077 - val_loss: 0.8387 - val_accuracy: 0.6245 - 356ms/epoch - 11ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 0.7986 - accuracy: 0.6354 - val_loss: 0.7568 - val_accuracy: 0.6560 - 357ms/epoch - 11ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 0.7102 - accuracy: 0.7001 - val_loss: 0.6583 - val_accuracy: 0.7210 - 350ms/epoch - 11ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 0.6000 - accuracy: 0.7971 - val_loss: 0.5428 - val_accuracy: 0.8375 - 350ms/epoch - 11ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 0.4947 - accuracy: 0.8570 - val_loss: 0.4555 - val_accuracy: 0.8710 - 353ms/epoch - 11ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 0.4291 - accuracy: 0.8717 - val_loss: 0.4135 - val_accuracy: 0.8780 - 346ms/epoch - 11ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 0.3935 - accuracy: 0.8766 - val_loss: 0.3829 - val_accuracy: 0.8810 - 359ms/epoch - 11ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 0.3721 - accuracy: 0.8780 - val_loss: 0.3658 - val_accuracy: 0.8805 - 361ms/epoch - 11ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 0
# Epoch 95/100
# 32/32 - 0s - loss: 0.1064 - accuracy: 0.9756 - val_loss: 0.1083 - val_accuracy: 0.9750 - 352ms/epoch - 11ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 0.1033 - accuracy: 0.9760 - val_loss: 0.1053 - val_accuracy: 0.9750 - 356ms/epoch - 11ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 0.1030 - accuracy: 0.9758 - val_loss: 0.1027 - val_accuracy: 0.9745 - 364ms/epoch - 11ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 0.0992 - accuracy: 0.9776 - val_loss: 0.1048 - val_accuracy: 0.9750 - 358ms/epoch - 11ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 0.0986 - accuracy: 0.9762 - val_loss: 0.1009 - val_accuracy: 0.9745 - 357ms/epoch - 11ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 0.0960 - accuracy: 0.9774 - val_loss: 0.0986 - val_accuracy: 0.9765 - 360ms/epoch - 11ms/step

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-fd1973793e0b> in <module>
#      18     plt.show()
#      19 Show_history(fit)
# ---> 20 Show_weights(model,0)
#      21 Show_weights(model,2)
#
# <ipython-input-74-d64b01653919> in Show_weights(model, l, label)
#      14     ax.plot((0,))
#      15     for i in range(M):
# ---> 16         ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
#      17     ax.set_title(label+': filters of layer '+str(l))
#      18     ax.set_xlabel('index')
#
# IndexError: list index out of range

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
#model2.layers[0].kernel_regularizer = reg2
#model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 250
EPOCHS2 = 100
Show_weights(model2,0)
Show_weights(model2,2)
fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-2f4f9c746226> in <module>
#       8 BATCH_SIZE2 = 250
#       9 EPOCHS2 = 100
# ---> 10 Show_weights(model2,0)
#      11 Show_weights(model2,2)
#      12 fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
#
# <ipython-input-74-d64b01653919> in Show_weights(model, l, label)
#      14     ax.plot((0,))
#      15     for i in range(M):
# ---> 16         ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
#      17     ax.set_title(label+': filters of layer '+str(l))
#      18     ax.set_xlabel('index')
#
# IndexError: list index out of range

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-c78f5d7e0ccd> in <module>
#       1 Show_history(fit)
#       2 Show_history(fit2)
# ----> 3 Show_weights(model2,0,label="model2")
#       4 Show_weights(model2,2,label="model2")
#
# <ipython-input-74-d64b01653919> in Show_weights(model, l, label)
#      14     ax.plot((0,))
#      15     for i in range(M):
# ---> 16         ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
#      17     ax.set_title(label+': filters of layer '+str(l))
#      18     ax.set_xlabel('index')
#
# IndexError: list index out of range

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
